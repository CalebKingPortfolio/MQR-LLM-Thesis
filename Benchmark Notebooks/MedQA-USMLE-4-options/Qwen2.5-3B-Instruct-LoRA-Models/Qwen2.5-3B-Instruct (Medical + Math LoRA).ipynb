# %% [markdown]
# **1. Install Libraries**

# %%
# !pip install -U "lm_eval[hf]"

# import librarys
import os
import lm_eval
from lm_eval.tasks import TaskManager
import zipfile
from peft import PeftModel
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# mount to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 2.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 98.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 11.9 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=e929a0ff3a5162ca7bdb35ab5c62fda5975e0e49ca25c246df77ed5245a034af
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# ...
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=12206c3d3eae270d87d45d3d12cc396fc7cdee11090cb1479a0697bbf8813eb1
# ...

# %% [markdown]
# **2. Load HF Token**

# %%
os.environ["HF_TOKEN"] = "add key"

# %% [markdown]
# **3. Examine Dataset**

# %%
# load the task
task_manager = TaskManager()
task_dict = lm_eval.tasks.get_task_dict(["medqa_4options"], task_manager)
task = task_dict["medqa_4options"]

# build the dataset
task.build_all_requests(rank=0, world_size=1)

# print dataset size
test_docs = list(task.test_docs())
print(f"Test set size: {len(test_docs)}")

# print first example prompt
print("\n" + "="*50)
print("EXAMPLE PROMPT:")
print("="*50)
example = test_docs[0]
print(task.doc_to_text(example))
print("\n" + "="*50)
print("CORRECT ANSWER:")
print("="*50)
print(task.doc_to_target(example))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md:   0%|          | 0.00/640 [00:00<?, ?B/s]
# train.json: 0.00B [00:00, ?B/s]
# dev.json: 0.00B [00:00, ?B/s]
# test.json: 0.00B [00:00, ?B/s]
# ...
# 100%|██████████| 1273/1273 [00:00<00:00, 65632.67it/s]
# Test set size: 1273
#
# ...
# EXAMPLE PROMPT:
# ...

# %% [markdown]
# **4. Load LoRA Adaptar Qwen2.5-3B-Instruct (Medical + Math LoRA) Convert From Zip**

# %%
# unzip the lora adapter
zip_path = "/content/drive/MyDrive/Fine-Tuning-Notebooks/Low-Rank-Adaptation-(LoRA)/Qwen2.5-3B-Instruct/Medical-Math/medical-math_qwen2.5_lora_adapter.zip"
extract_path = "/content/qwen_medical_math_lora_adapter"

os.makedirs(extract_path, exist_ok=True)
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Unzipped!")
print(f"Adapter location: {extract_path}")
print(os.listdir(extract_path))
# Out:
# Unzipped!
# Adapter location: /content/qwen_medical_math_lora_adapter
# ['medical-math_qwen2.5_lora_adapter']

# %% [markdown]
# **5. Load Base Model and Apply Adaptar**

# %%
# path to the unzipped lora adapter
adapter_path = "/content/qwen_medical_math_lora_adapter/medical-math_qwen2.5_lora_adapter"

# base model name from hugging face
base_model_name = "Qwen/Qwen2.5-3B-Instruct"

# loads the tokenizer from the base model
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(base_model_name)

# add padding token if missing
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# loads the base model
print("Loading base model...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

# loads the lora adapter on top of the base model
print("Loading LoRA adapter...")
model = PeftModel.from_pretrained(model, adapter_path)

# merge and unload for lm-eval
print("Merging LoRA adapter...")
model = model.merge_and_unload()

# save merged model
print("Saving merged model...")
model.save_pretrained("/content/qwen_medical_math_lora")
tokenizer.save_pretrained("/content/qwen_medical_math_lora")

# confirm paths and files
print(f"\nAdapter path:      {adapter_path}")
print(f"Merged model path: /content/qwen_medical_math_lora")
print(f"Files:             {os.listdir('/content/qwen_medical_math_lora')}")
print("Ready for lm-eval!")
# Out:
# Loading tokenizer...
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading base model...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Loading LoRA adapter...
# Merging LoRA adapter...
# Saving merged model...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Adapter path:      /content/qwen_medical_math_lora_adapter/medical-math_qwen2.5_lora_adapter
# Merged model path: /content/qwen_medical_math_lora
# Files:             ['model.safetensors', 'tokenizer.json', 'config.json', 'chat_template.jinja', 'tokenizer_config.json', 'generation_config.json']
# Ready for lm-eval!

# %% [markdown]
# **6. Perform Evaluation (medqa_4options)**

# %%
# !lm-eval run \
  --model hf \
  --model_args pretrained=/content/qwen_medical_math_lora \
  --tasks medqa_4options \
  --device cuda:0 \
  --batch_size 8 \
  --apply_chat_template \
  --output_path /content/drive/MyDrive/Model-Evaluations/MedQA-USMLE-4-options/Qwen2.5-3B-Instruct-LoRA-Models/qwen_medical_math_lora
# Out:
# 2026-04-22:21:58:31 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-22:21:58:36 INFO     [_cli.run:376] Selected Tasks: ['medqa_4options']
# 2026-04-22:21:58:38 INFO     [evaluator:211] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-04-22:21:58:38 INFO     [evaluator:236] Initializing hf model, with arguments: {'pretrained': '/content/qwen_medical_math_lora'}
# 2026-04-22:21:58:42 INFO     [models.huggingface:161] Using device 'cuda:0'
# 2026-04-22:21:58:43 INFO     [models.huggingface:423] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# Loading weights: 100% 434/434 [00:01<00:00, 279.47it/s, Materializing param=model.norm.weight]
# 2026-04-22:21:58:47 INFO     [tasks:700] Selected tasks:
# 2026-04-22:21:58:47 INFO     [tasks:691] Task: medqa_4options (medqa/medqa.yaml)
# ...
