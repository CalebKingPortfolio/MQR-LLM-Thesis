# %% [markdown]
# **1. Install Libraries**

# %%
# !pip install -U "lm_eval[hf]"

# import librarys
import os
import lm_eval
from lm_eval.tasks import TaskManager
import zipfile

# mount to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.2 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=9306b9263074317a280ae1d76bf2351ac945ac8e7f76905aaec719fef0957f66
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# ...
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=8b7ddffa79bcab96c448817959b0bc433e729fb00024193f8bdb13283a4a26c2
# ...

# %% [markdown]
# **2. Load HF Token**

# %%
os.environ["HF_TOKEN"] = "add key"

# %% [markdown]
# **3. Examine Dataset**

# %%
# load the task
task_manager = TaskManager()
task_dict = lm_eval.tasks.get_task_dict(["medqa_4options"], task_manager)
task = task_dict["medqa_4options"]

# build the dataset
task.build_all_requests(rank=0, world_size=1)

# print dataset size
test_docs = list(task.test_docs())
print(f"Test set size: {len(test_docs)}")

# print first example prompt
print("\n" + "="*50)
print("EXAMPLE PROMPT:")
print("="*50)
example = test_docs[0]
print(task.doc_to_text(example))
print("\n" + "="*50)
print("CORRECT ANSWER:")
print("="*50)
print(task.doc_to_target(example))
# Out:
# README.md:   0%|          | 0.00/640 [00:00<?, ?B/s]
# train.json: 0.00B [00:00, ?B/s]
# dev.json: 0.00B [00:00, ?B/s]
# test.json: 0.00B [00:00, ?B/s]
# ...
# 100%|██████████| 1273/1273 [00:00<00:00, 56914.81it/s]
# Test set size: 1273
#
# ...
# EXAMPLE PROMPT:
# ...
# Question: A junior orthopaedic surgery resident is completing a carpal tunnel repair with the department chairman as the attending physician. During the case, the resident inadvertently cuts a flexor tendon. The tendon is repaired without complication. The attending tells the resident that the patient will do fine, and there is no need to report this minor complication that will not harm the patient, as he does not want to make the patient worry unnecessarily. He tells the resident to leave this complication out of the operative report. Which of the following is the correct next action for the resident to take?
# A. Disclose the error to the patient and put it in the operative report
# ...

# %% [markdown]
# **4. Load Full Model Llama-3.2-3B-Instruct (Medical + Math Full) Convert From Zip**

# %%
# path to the zipped model in Google Drive
zip_path = "/content/drive/MyDrive/Fine-Tuning-Notebooks/Full-Fine-Tuning/Llama-3.2-3B-Instruct/Medical-Math/medical-math_llama3_full_model.zip"

# folder to extract the model into
extract_path = "/content/llama_medical_math_full"

# make the folder if it does not exist
os.makedirs(extract_path, exist_ok=True)

# unzip the model
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# print to check it worked
print("Unzipped!")

# show files in main folder
print(os.listdir(extract_path))

# show actual model files
print(os.listdir(f"{extract_path}/medical-math_llama3_full_model"))
# Out:
# Unzipped!
# ['medical-math_llama3_full_model']
# ['model.safetensors', 'tokenizer.json', 'config.json', 'chat_template.jinja', 'tokenizer_config.json', 'generation_config.json']

# %% [markdown]
# **5. Perform Evaluation (medqa_4options)**

# %%
# !lm-eval run \
  --model hf \
  --model_args pretrained=/content/llama_medical_math_full/medical-math_llama3_full_model \
  --tasks medqa_4options \
  --device cuda:0 \
  --batch_size 8 \
  --apply_chat_template \
  --output_path /content/drive/MyDrive/Model-Evaluations/MedQA-USMLE-4-options/Llama-3.2-3B-Instruct-Full-Models
# Out:
# 2026-04-22:10:25:33 INFO     [config.evaluate_config:301] Using default fewshot_as_multiturn=True.
# 2026-04-22:10:25:41 INFO     [_cli.run:376] Selected Tasks: ['medqa_4options']
# 2026-04-22:10:25:45 INFO     [evaluator:211] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-04-22:10:25:45 INFO     [evaluator:236] Initializing hf model, with arguments: {'pretrained': '/content/llama_medical_math_full/medical-math_llama3_full_model'}
# 2026-04-22:10:25:56 INFO     [models.huggingface:161] Using device 'cuda:0'
# 2026-04-22:10:25:58 INFO     [models.huggingface:423] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# Loading weights: 100% 254/254 [00:21<00:00, 11.57it/s, Materializing param=model.norm.weight]
# 2026-04-22:10:26:24 INFO     [tasks:700] Selected tasks:
# 2026-04-22:10:26:24 INFO     [tasks:691] Task: medqa_4options (medqa/medqa.yaml)
# ...
